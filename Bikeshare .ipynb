# %%
import time
import pandas as pd
import numpy as np

# %%
# Load 2014 to 2017 Bike Data from Chicago 

df_c_2014_Q1Q2 = pd.read_csv("data/Chicago/Divvy_Trips_2014_Q1Q2/Divvy_Trips_2014_Q1Q2.csv")
df_c_2014_Q3_1 = pd.read_csv("data/Chicago/Divvy_Trips_2014_Q3Q4/Divvy_Trips_2014-Q3-07.csv")
df_c_2014_Q3_2 = pd.read_csv("data/Chicago/Divvy_Trips_2014_Q3Q4/Divvy_Trips_2014-Q3-0809.csv")
df_c_2014_Q4 = pd.read_csv("data/Chicago/Divvy_Trips_2014_Q3Q4/Divvy_Trips_2014-Q4.csv")
df_c_2015_Q1 = pd.read_csv("data/Chicago/Divvy_Trips_2015-Q1Q2/Divvy_Trips_2015-Q1.csv")
df_c_2015_Q2 = pd.read_csv("data/Chicago/Divvy_Trips_2015-Q1Q2/Divvy_Trips_2015-Q2.csv")
df_c_2015_Q3_1 = pd.read_csv("data/Chicago/Divvy_Trips_2015_Q3Q4/Divvy_Trips_2015_07.csv")
df_c_2015_Q3_2 = pd.read_csv("data/Chicago/Divvy_Trips_2015_Q3Q4/Divvy_Trips_2015_08.csv")
df_c_2015_Q3_3 = pd.read_csv("data/Chicago/Divvy_Trips_2015_Q3Q4/Divvy_Trips_2015_09.csv")
df_c_2015_Q4 = pd.read_csv("data/Chicago/Divvy_Trips_2015_Q3Q4/Divvy_Trips_2015_Q4.csv")
df_c_2016_Q1 = pd.read_csv("data/Chicago/Divvy_Trips_2016_Q1Q2/Divvy_Trips_2016_Q1.csv")
df_c_2016_Q2_1 = pd.read_csv("data/Chicago/Divvy_Trips_2016_Q1Q2/Divvy_Trips_2016_04.csv")
df_c_2016_Q2_2 = pd.read_csv("data/Chicago/Divvy_Trips_2016_Q1Q2/Divvy_Trips_2016_05.csv")
df_c_2016_Q2_3 = pd.read_csv("data/Chicago/Divvy_Trips_2016_Q1Q2/Divvy_Trips_2016_06.csv")
df_c_2016_Q3 = pd.read_csv("data/Chicago/Divvy_Trips_2016_Q3Q4/Divvy_Trips_2016_Q3.csv")
df_c_2016_Q4 = pd.read_csv("data/Chicago/Divvy_Trips_2016_Q3Q4/Divvy_Trips_2016_Q4.csv")
df_c_2017_Q1 = pd.read_csv("data/Chicago/Divvy_Trips_2017_Q1Q2/Divvy_Trips_2017_Q1.csv")
df_c_2017_Q2 = pd.read_csv("data/Chicago/Divvy_Trips_2017_Q1Q2/Divvy_Trips_2017_Q2.csv")
df_c_2017_Q3 = pd.read_csv("data/Chicago/Divvy_Trips_2017_Q3Q4/Divvy_Trips_2017_Q3.csv")
df_c_2017_Q4 = pd.read_csv("data/Chicago/Divvy_Trips_2017_Q3Q4/Divvy_Trips_2017_Q4.csv")

frames_c = [df_c_2014_Q1Q2, df_c_2014_Q3_1, df_c_2014_Q3_2, df_c_2014_Q4, df_c_2015_Q1, df_c_2015_Q2,\
            df_c_2015_Q3_1, df_c_2015_Q3_2, df_c_2015_Q3_3, df_c_2015_Q4, df_c_2016_Q1, df_c_2016_Q2_1, df_c_2016_Q2_2,  df_c_2016_Q2_3,\
            df_c_2016_Q3, df_c_2016_Q4, df_c_2017_Q1, df_c_2017_Q2, df_c_2016_Q3, df_c_2016_Q4]

result_c = pd.concat(frames_c, sort = True)

# %%
# Load 2014 to 2017 Bike Data from Washington

df_w_2014_Q1 = pd.read_csv("data/Washington/2014-capitalbikeshare-tripdata/2014Q1-capitalbikeshare-tripdata.csv")
df_w_2014_Q2 = pd.read_csv("data/Washington/2014-capitalbikeshare-tripdata/2014Q2-capitalbikeshare-tripdata.csv")
df_w_2014_Q3 = pd.read_csv("data/Washington/2014-capitalbikeshare-tripdata/2014Q3-capitalbikeshare-tripdata.csv")
df_w_2014_Q4 = pd.read_csv("data/Washington/2014-capitalbikeshare-tripdata/2014Q4-capitalbikeshare-tripdata.csv")
df_w_2015_Q1 = pd.read_csv("data/Washington/2015-capitalbikeshare-tripdata/2015Q1-capitalbikeshare-tripdata.csv")
df_w_2015_Q2 = pd.read_csv("data/Washington/2015-capitalbikeshare-tripdata/2015Q2-capitalbikeshare-tripdata.csv")
df_w_2015_Q3 = pd.read_csv("data/Washington/2015-capitalbikeshare-tripdata/2015Q3-capitalbikeshare-tripdata.csv")
df_w_2015_Q4 = pd.read_csv("data/Washington/2015-capitalbikeshare-tripdata/2015Q4-capitalbikeshare-tripdata.csv")
df_w_2016_Q1 = pd.read_csv("data/Washington/2016-capitalbikeshare-tripdata/2016Q1-capitalbikeshare-tripdata.csv")
df_w_2016_Q2 = pd.read_csv("data/Washington/2016-capitalbikeshare-tripdata/2016Q2-capitalbikeshare-tripdata.csv")
df_w_2016_Q3 = pd.read_csv("data/Washington/2016-capitalbikeshare-tripdata/2016Q3-capitalbikeshare-tripdata.csv")
df_w_2016_Q4 = pd.read_csv("data/Washington/2016-capitalbikeshare-tripdata/2016Q4-capitalbikeshare-tripdata.csv")
df_w_2017_Q1 = pd.read_csv("data/Washington/2017-capitalbikeshare-tripdata/2017Q1-capitalbikeshare-tripdata.csv")
df_w_2017_Q2 = pd.read_csv("data/Washington/2017-capitalbikeshare-tripdata/2017Q2-capitalbikeshare-tripdata.csv")
df_w_2017_Q3 = pd.read_csv("data/Washington/2017-capitalbikeshare-tripdata/2017Q3-capitalbikeshare-tripdata.csv")
df_w_2017_Q4 = pd.read_csv("data/Washington/2017-capitalbikeshare-tripdata/2017Q4-capitalbikeshare-tripdata.csv")

frames_w = [df_w_2014_Q1, df_w_2014_Q2, df_w_2014_Q3, df_w_2014_Q4,\
            df_w_2015_Q1, df_w_2015_Q2, df_w_2015_Q3, df_w_2015_Q4,\
            df_w_2016_Q1, df_w_2016_Q2, df_w_2016_Q3, df_w_2016_Q4,\
            df_w_2017_Q1, df_w_2017_Q2, df_w_2017_Q3, df_w_2017_Q4]

result_w = pd.concat(frames_w, sort = True)

# %%
CITY_DATA = { 'chicago': result_c,
              'washington': result_w}

# %%
def get_filters():
    """
    Asks user to specify a city, month, and day to analyze.

    Returns:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    """
    print('Hello! Let\'s explore some US bikeshare data!')
    
    # get user input for the city
    while True:
        city = input('What is the city?\n')
        city = city.lower()
        if city not in ('chicago', 'washington'):
            print('Sorry, which city would you like to explore? Chicago or Washington?')
        else:
            break

    # get user input for month
    while True:
        month = input('What is the month you would like to explore?\n')
        month = month.lower()
        if month not in ('all', 'january', 'february', 'march', 'april', 'may', 'june', 'july', 'august', 'september', 'october', 'november', 'december'):
            print('Sorry, which month would you like to explore? Please enter ALL or single month.')
        else:
            break

    # get user input for day of week
    while True:
        day = input('What is the day?\n')
        day = day.lower()
        if day not in ('all', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday'):
            print('Sorry, which day of week would you like to explore? Please enter ALL or a day of week')
        else:
            break

    print('-'*40)
    return city, month, day

# %%
def load_data(city, month, day):
    """
    Loads data for the specified city and filters by month and day if applicable.

    Args:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    Returns:
        df - Pandas DataFrame containing city data filtered by month and day
    """
    # load data file into a dataframe
    df = CITY_DATA[city]

    # convert the Start Time column to datetime
    df['Start Time'] = pd.to_datetime(df['Start Time'])

    # extract month and day of week from Start Time to create new columns
    df['month'] = df['Start Time'].dt.month
    df['day_of_week'] = df['Start Time'].dt.weekday_name

    # filter by month if applicable
    if month != 'all':

        # use the index of the months list to get the corresponding int
        months = ['january', 'february', 'march', 'april', 'may', 'june']
        month = months.index(month) + 1

        # filter by month to create the new dataframe
        df = df[df['month'] == month]

    # filter by day of week if applicable
    if day != 'all':
        # filter by day of week to create the new dataframe
        df = df[df['day_of_week'] == day.title()]

    return df

# %%
def time_stats(df):
    """Displays statistics on the most frequent times of travel."""

    print('\nCalculating The Most Frequent Times of Travel...\n')
    start_time = time.time()
    df['Start Time'] = pd.to_datetime(df['Start Time'])

    # TO DO: display the most common month
    df['month'] = df['Start Time'].dt.month
    common_month = df['month'].mode()[0]
    print('Most Common Travel Month:\n', common_month)

    # TO DO: display the most common day of week
    df['day'] = df['Start Time'].dt.weekday_name
    common_day = df['day'].mode()[0]
    print('Most Common Travel Day:\n', common_day)

    # TO DO: display the most common start hour
    df['hour'] = df['Start Time'].dt.hour
    common_hour = df['hour'].mode()[0]
    print('Most Common Travel Hour (in military time):\n', common_hour)

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def station_stats(df):
    """Displays statistics on the most popular stations and trip."""

    print('\nCalculating The Most Popular Stations and Trip...\n')
    start_time = time.time()

    # TO DO: display most commonly used start station
    start_station = df['Start Station'].value_counts()
    print('Most Common Used Start Station:\n', start_station.idxmax())

    # TO DO: display most commonly used end station
    end_station = df['End Station'].value_counts()
    print('Most Common Used End Station:\n', end_station.idxmax())


    # TO DO: display most frequent combination of start station and end station trip
    combination = df.groupby(['Start Station', 'End Station']).size()
    print('Most Frequent Combination of Start Station and End Station Trip:\n', combination.idxmax())

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def trip_duration_stats(df):
    """Displays statistics on the total and average trip duration."""

    print('\nCalculating Trip Duration...\n')
    start_time = time.time()

    # TO DO: display total travel time
    total = df['Trip Duration'].sum()
    minute, second = divmod(total, 60)
    hour, minute = divmod(minute, 60)
    print('Total travel Time is {} hours, {} minutes and {} seconds.'.format(hour, minute, second))

    # TO DO: display mean travel time
    mean = df['Trip Duration'].mean()
    mi, sec = divmod(mean, 60)
    if mi > 60:
        hr, mi = divmod(mi, 60)
        print('The average travel Time is {} hours, {} minutes and {} seconds.'.format(hr, mi, sec))
    else:
        print('The average travel Time is {} minutes and {} seconds.'.format(mi, sec))

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def user_stats(df):
    """Displays statistics on bikeshare users."""

    print('\nCalculating User Stats...\n')
    start_time = time.time()

    # TO DO: Display counts of user types
    user_types = df['User Type'].value_counts()
    print('Counts of User Types:\n', user_types)

    # TO DO: Display counts of gender
    while True:
        city = input('What is the city again?\n')
        city = city.lower()
        if city == 'washington':
            print('Sorry, there is no gender and birth year data.')
            break
        else:
            gender = df['Gender'].value_counts()
            print('Counts of Gender:\n', gender)

    # TO DO: Display earliest, most recent, and most common year of birth
            earliest_year = df['Birth Year'].min()
            most_recent_year = df['Birth Year'].max()
            most_common_year = df['Birth Year'].mode()

            print('The oldest user(s) are born in {}.\nThe youngest user(s) are born in {}.\nThe most common birth year is {}.'.format(earliest_year, most_recent_year, most_common_year)
            break

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def main():
    while True:
        city, month, day = get_filters()
        df = load_data(city, month, day)

        time_stats(df)
        station_stats(df)
        trip_duration_stats(df)
        user_stats(df)

        restart = input('\nWould you like to restart? Enter yes or no.\n')
        if restart.lower() != 'yes':
            break


if __name__ == "__main__":
	main()
